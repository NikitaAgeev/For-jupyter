# %%
import numpy as np
import math
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Если используете Jupyter, то можно поменять backend matplotlib на notebook
# %matplotlib notebook
# Для использования backend matplotlib widget, раскомментируйте строку ниже.
# %matplotlib widget
# Для использования backend matplotlib inline, раскомментируйте строку ниже.
# %matplotlib inline

# %% [markdown]
# Мне лень преписывать задачу(
#
#
# ### Начальные условия
# (они сказали, что боковые должны быть периодическими и всё)

# %%
L = 10
T = 9

curant = 0.6

N_h = 50

h = L/N_h
tau = curant*h

N_tau = int(T/tau) + 1

a = 1

#Начальное
def zero_time_F(x):
    return np.sin(2*np.pi*x/L)
    #return 0;

#правое и левое
def zero_x_l_F(t):
    return zero_time_F(-a*t)
    #return 0;

def zero_x_r_F(t):
    return zero_time_F(L - a*t)
    #return 0;

# f
def f(x, t):
    return 0;

N_tau
# Out:
# 76

# %% [markdown]
# ## На посмотреть
#
# ### Схема Лакса

# %%
#Генерируем нулевой слой
x_ans = [[zero_time_F(i*h) for i in range(0, N_h+1)]]
#print(x_ans)


for j in range(1, N_tau + 1):
    mid_res = [tau*f(0, tau*j) - a*(x_ans[-1][1] - x_ans[-1][-2])*(tau/(2*h)) + 0.5*(x_ans[-1][1] + x_ans[-1][-2])]
    for i in range (1 , N_h):
        mid_res = np.append(mid_res,  [tau*f(i*h, tau*j) - a*(x_ans[-1][i+1] - x_ans[-1][i-1])*(tau/(2*h)) + 0.5*(x_ans[-1][i+1] + x_ans[-1][i-1])])
    mid_res = np.append(mid_res, [mid_res[0]])
    x_ans = np.append(x_ans, [mid_res], axis = 0)

#x_ans[-1]

# %%
x1 = [np.linspace(0, L, num = N_h + 1)]
t1 = [np.linspace(0, T, num = N_tau + 1)]
x = x1
t = t1
for i in range(N_tau):
    x = np.append(x, x1, axis = 0)
for i in range(N_h):
    t = np.append(t, t1, axis = 0)
#print(x)
#print(np.transpose(t))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_zlabel('u')
ax.scatter(x, np.transpose(t), x_ans)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ### Схема Лакса-Вендрофа

# %%
#Генерируем нулевой слой
x_ans = [[zero_time_F(i*h) for i in range(0, N_h+1)]]
#print(x_ans)


for j in range(1, N_tau + 1):
    mid_res = [tau*f(i*h, tau*j) - a*(x_ans[-1][1] - x_ans[-1][-2])*(tau/(2*h)) + x_ans[-1][0] + (a**2 *tau**2/(2*h**2))*(x_ans[-1][1] - 2*x_ans[-1][0] + x_ans[-1][-2])]
    for i in range (1 , N_h):
        mid_res = np.append(mid_res,  [tau*f(i*h, tau*j) - a*(x_ans[-1][i+1] - x_ans[-1][i-1])*(tau/(2*h)) + x_ans[-1][i] + (a**2 *tau**2/(2*h**2))*(x_ans[-1][i+1] - 2*x_ans[-1][i] + x_ans[-1][i-1])])
    mid_res = np.append(mid_res, [mid_res[0]])
    x_ans = np.append(x_ans, [mid_res], axis = 0)

#x_ans[-1]

# %%
x1 = [np.linspace(0, L, num = N_h + 1)]
t1 = [np.linspace(0, T, num = N_tau + 1)]
x = x1
t = t1
for i in range(N_tau):
    x = np.append(x, x1, axis = 0)
for i in range(N_h):
    t = np.append(t, t1, axis = 0)
#print(x)
#print(np.transpose(t))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('x')
ax.set_ylabel('t')
ax.set_zlabel('u')
ax.scatter(x, np.transpose(t), x_ans)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Исследования
#
# тут будут более оптимальные по памяти решения для ускорения, но они только невязку дадут

# %%
L = 10
T = 9

curant = 1

N_h = 500

h = L/N_h
tau = curant*h

N_tau = int(T/tau) + 1

a = 1

#Начальное
def zero_time_F(x):
    return np.sin(2*np.pi*x/L)
    #return 0;

#правое и левое
def zero_x_l_F(t):
    return zero_time_F(-a*t)
    #return 0;

def zero_x_r_F(t):
    return zero_time_F(L - a*t)
    #return 0;

def real_F(x, t):
    return zero_time_F(x - a*t)
    
# f
def f(x, t):
    return 0;

N_tau
# Out:
# 451

# %% [markdown]
# ### Схема Лакса

# %%
#Генерируем нулевой слой
x_ans = [zero_time_F(i*h) for i in range(0, N_h+1)]
#print(x_ans)

delta = 0;

for j in range(1, N_tau + 1):
    mid_res = [tau*f(0, tau*j) - a*(x_ans[1] - x_ans[-2])*(tau/(2*h)) + 0.5*(x_ans[1] + x_ans[-2])]
    for i in range (1 , N_h):
        mid_res = np.append(mid_res,  [tau*f(i*h, tau*j) - a*(x_ans[i+1] - x_ans[i-1])*(tau/(2*h)) + 0.5*(x_ans[i+1] + x_ans[i-1])])
    mid_res = np.append(mid_res, [mid_res[0]])
    real_ans = [real_F(i*h, j*tau) for i in range(0, N_h + 1)]
    delta = max(delta, np.max((mid_res - real_ans)**2))
    x_ans = mid_res 

#x_ans[-1]
print(np.sqrt(delta))
# Out:
# 1.942890293094024e-15

# %%
#Таблица результатов
#curant 1
#500 1.1470087626415044e-28 
#1000 2.277951420395101e-28
#2000 4.583572992511886e-28

x = [1.8318679906315083e-15,1.887379141862766e-15, 1.942890293094024e-15]
N =[500, 1000, 2000]

k, b =np.polyfit(-np.log(N), np.log(x), 1)

print("Polyfit cur 1:", k)
#P.s. тут похоже проблема в том, что при Curant = 1 и a = 1 мы идеально попадаем в сетку


#curant 0.6
#500 0.03134304876598548
#1000 0.015892345338117342
#2000 0.008002997312686388

x = [0.037239009300130466,0.018783654770036518, 0.009433208344229782]
N =[500, 1000, 2000]

k, b =np.polyfit(-np.log(N), np.log(x), 1)

print("Polyfit cur 0.6:", k)

#curant 0.3
#500 0.08538780847354677 
#1000 0.04418215721649321
#2000 0.02249360372539244

x = [0.10223797581268779, 0.05247910852872606, 0.02658867484590932]
N =[500, 1000, 2000]

k, b =np.polyfit(-np.log(N), np.log(x), 1)

print("Polyfit cur 0.3:", k)

#P.s. точность чёт такая себе, но тут правый край плывёт немного и это какая-то беда схемы
# Out:
# Polyfit cur 1: -0.04244444879325449
# Polyfit cur 0.6: 0.9904971276585967
# Polyfit cur 0.3: 0.9715236982580618

# %% [markdown]
# Схема лакса имеет 1 порядок сходимости по времени и 2 по по пространству(Если не учитывать h^2/tau). Из-за этого общий порядок сходимости при фиксированном числе Куранта 1.

# %% [markdown]
# ### Схема Лакса-Вендрофа

# %%
#Генерируем нулевой слой
x_ans = [zero_time_F(i*h) for i in range(0, N_h+1)]
#print(x_ans)

delta = 0;

for j in range(1, N_tau + 1):
    mid_res = [tau*f(0, tau*j) - a*(x_ans[1] - x_ans[-2])*(tau/(2*h)) + x_ans[0] + (a**2 *tau**2/(2*h**2))*(x_ans[1] - 2*x_ans[0] + x_ans[-2])]
    for i in range (1 , N_h):
        mid_res = np.append(mid_res,  [tau*f(i*h, tau*j) - a*(x_ans[i+1] - x_ans[i-1])*(tau/(2*h)) + x_ans[i] + (a**2 *tau**2/(2*h**2))*(x_ans[i+1] - 2*x_ans[i] + x_ans[i-1])])
    mid_res = np.append(mid_res, [mid_res[0]])
    real_ans = [real_F(i*h, j*tau) for i in range(0, N_h + 1)]
    delta = max(delta, np.max((mid_res - real_ans)**2))
    x_ans = mid_res 

#x_ans[-1]
print(np.sqrt(delta))
# Out:
# 1.8318679906315083e-15

# %%
#Таблица результатов
#curant 1
#500 1.1480394962736161e-28 
#1000 2.2907119099828816e-28
#2000 4.60649826198908e-28

x = [1.8318679906315083e-15, 1.9984014443252818e-15, 1.942890293094024e-15]
N =[500, 1000, 2000]

k, b =np.polyfit(-np.log(N), np.log(x), 1)

print("Polyfit cur 1:", k)
#P.s. тут похоже проблема в том, что при Curant = 1 и a = 1 мы идеально попадаем в сетку


#curant 0.6
#500 9.705792863656804e-05 
#1000 2.417361235074189e-05
#2000 6.031901586434074e-06

x = [9.537724222328375e-05, 2.3828631198547032e-05, 5.95518551114462e-06]
N =[500, 1000, 2000]

k, b =np.polyfit(-np.log(N), np.log(x), 1)

print("Polyfit cur 0.6:", k)

#curant 0.3
#500 2.2594553587440733e-06 
#1000 2.8192188368337694e-07
#2000 3.520833148146132e-08

x = [0.00013552452273506588, 3.38700669991485e-05, 8.466119748903119e-06]
N =[500, 1000, 2000]

k, b =np.polyfit(-np.log(N), np.log(x), 1)

print("Polyfit cur 0.3:", k)
# Out:
# Polyfit cur 1: -0.04244444879325568
# Polyfit cur 0.6: 2.0007133565412585
# Polyfit cur 0.3: 2.000354610557349

# %% [markdown]
# Схема Лакса-Вендерофа имеет 2 порядок(при том честный) сходимости по x и t. Что подтверждает эксперимент
